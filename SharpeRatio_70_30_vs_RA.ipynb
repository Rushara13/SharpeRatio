# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns',None)
pd.set_option('display.width',None)
pd.set_option('display.max_colwidth',None)

# %%
#Portfoliorendite

dfr = pd.read_csv('Roboadvisor_returns.csv', index_col = 0)
dfr
# Out:
#             quirion  fintego  easyfolio
# 2015-05-31      1.2      0.4        0.3
# 2015-06-30     -2.6     -3.5       -3.0
# 2015-07-31      0.7      1.4        0.9
# 2015-08-31     -4.0     -4.4       -5.0
# 2015-09-30     -2.4     -1.2       -1.8
# 2015-10-31      4.9      4.6        4.9
# 2015-11-30      1.5      1.6        2.0
# 2015-12-31     -2.5     -3.5       -3.2
# 2016-01-31     -4.1     -2.3       -2.9
# 2016-02-29      0.9      0.2        0.1
# 2016-03-31      2.3      1.6        1.8
# 2016-04-30      0.8      1.1        0.6
# 2016-05-31      0.9      1.0        1.1
# 2016-06-30     -0.5      0.5        0.5
# 2016-07-31      2.7      2.6        2.4
# 2016-08-31      0.4     -0.2        0.5
# 2016-09-30     -0.2      0.4        0.0
# 2016-10-31      0.1     -0.8        0.1
# 2016-11-30      2.2      1.1        0.5
# 2016-12-31      1.5      1.3        1.3
# 2017-01-31      0.1     -0.3       -0.4
# 2017-02-28      2.2      2.8        2.6
# ...

# %%
# read etf return with and withour Rebalancing

dfe = pd.read_csv('70_30_returns.csv', index_col = 0)
dfe = dfe * 100
dfe
# Out:
#             70/30 Performance mit Reb.  70/30 Performance ohne Reb.
# Datum
# 2015-05-31                    1.166950                     1.166950
# 2015-06-30                   -3.886506                    -3.886506
# 2015-07-31                    1.311703                     1.311703
# 2015-08-31                   -8.622537                    -8.622537
# 2015-09-30                   -3.218136                    -3.218136
# 2015-10-31                    9.379733                     9.379733
# 2015-11-30                    3.393846                     3.393846
# 2015-12-31                   -4.368658                    -4.368658
# 2016-01-31                   -6.628287                    -6.628287
# 2016-02-29                    0.466589                     0.466589
# 2016-03-31                    2.133024                     2.133024
# 2016-04-30                   -0.058464                    -0.058464
# 2016-05-31                    2.801958                     3.357166
# ...

# %%
#monthly return of RA and 70/30 ETF with and without Rebalancing

mtl_return = pd.read_csv('mtl_return_70_30_vs_RA.csv', index_col = 0)
mtl_return = mtl_return * 100
mtl_return
# Out:
#             quirion  fintego  easyfolio  70/30 Performance mit Reb.  \
# Datum
# 2015-05-31      1.2      0.4        0.3                      1.1670
# 2015-06-30     -2.6     -3.5       -3.0                     -3.8865
# 2015-07-31      0.7      1.4        0.9                      1.3117
# 2015-08-31     -4.0     -4.4       -5.0                     -8.6225
# 2015-09-30     -2.4     -1.2       -1.8                     -3.2181
# 2015-10-31      4.9      4.6        4.9                      9.3797
# 2015-11-30      1.5      1.6        2.0                      3.3938
# 2015-12-31     -2.5     -3.5       -3.2                     -4.3687
# 2016-01-31     -4.1     -2.3       -2.9                     -6.6283
# 2016-02-29      0.9      0.2        0.1                      0.4666
# 2016-03-31      2.3      1.6        1.8                      2.1330
# 2016-04-30      0.8      1.1        0.6                     -0.0585
# 2016-05-31      0.9      1.0        1.1                      2.8020
# ...

# %%
rfr = 0.0355

# %%
excess_return = mtl_return - rfr
excess_return
# Out:
#             quirion  fintego  easyfolio  70/30 Performance mit Reb.  \
# Datum
# 2015-05-31   1.1645   0.3645     0.2645                      1.1315
# 2015-06-30  -2.6355  -3.5355    -3.0355                     -3.9220
# 2015-07-31   0.6645   1.3645     0.8645                      1.2762
# 2015-08-31  -4.0355  -4.4355    -5.0355                     -8.6580
# 2015-09-30  -2.4355  -1.2355    -1.8355                     -3.2536
# 2015-10-31   4.8645   4.5645     4.8645                      9.3442
# 2015-11-30   1.4645   1.5645     1.9645                      3.3583
# 2015-12-31  -2.5355  -3.5355    -3.2355                     -4.4042
# 2016-01-31  -4.1355  -2.3355    -2.9355                     -6.6638
# 2016-02-29   0.8645   0.1645     0.0645                      0.4311
# 2016-03-31   2.2645   1.5645     1.7645                      2.0975
# 2016-04-30   0.7645   1.0645     0.5645                     -0.0940
# 2016-05-31   0.8645   0.9645     1.0645                      2.7665
# ...

# %%
excess_return.mean()
# Out:
# quirion                        0.242278
# fintego                        0.240889
# easyfolio                      0.183944
# 70/30 Performance mit Reb.     0.745517
# 70/30 Performance ohne Reb.    0.748292
# dtype: float64

# %%
excess_return.std()
# Out:
# quirion                        2.408975
# fintego                        2.229981
# easyfolio                      2.431984
# 70/30 Performance mit Reb.     4.472646
# 70/30 Performance ohne Reb.    4.175445
# dtype: float64

# %%
sharpe_ratio = excess_return.mean()/ excess_return.std()
sharpe_ratio
# Out:
# quirion                        0.100573
# fintego                        0.108023
# easyfolio                      0.075636
# 70/30 Performance mit Reb.     0.166684
# 70/30 Performance ohne Reb.    0.179212
# dtype: float64
